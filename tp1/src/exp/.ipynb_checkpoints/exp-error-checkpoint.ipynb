# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
#import plotly.graph_objs as go

# %%
df = pd.read_csv('resultados/random-var-m-p-data.csv', sep=',', engine='python')
# print(df)

cant_nodos = df["n"][0]
df["p"] = np.around(df["p"], decimals=2)
ax = sns.heatmap(data = df.groupby(['p','p_densidad'], as_index=False).mean().pivot('p','p_densidad', 'val'),cmap="Blues")
ax.set_title("Error de cuentas según densidades y p".format(cant_nodos))
ax.invert_yaxis()
ax.set_yticklabels(ax.get_yticklabels(), rotation = 0)
plt.xlabel(r'Páginas')
plt.ylabel(r'p')
plt.savefig('img/random-var-m-p.png')
plt.show()

df = pd.read_csv('resultados/random-var-m-p-data-mucha-densidad.csv', sep=',', engine='python')
# print(df)

cant_nodos = df["n"][0]
df["p"] = np.around(df["p"], decimals=2)
ax = sns.heatmap(data = df.groupby(['p','p_densidad'], as_index=False).mean().pivot('p','p_densidad', 'val'),cmap="Blues")
ax.set_title("Error de cuentas según densidades y p".format(cant_nodos))
ax.invert_yaxis()
ax.set_yticklabels(ax.get_yticklabels(), rotation = 0)
plt.xlabel(r'Páginas')
plt.ylabel(r'p')
plt.savefig('img/random-var-m-p.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-569ddde7d6ea> in <module>()
#      13 plt.show()
#      14
# ---> 15 df = pd.read_csv('resultados/random-var-m-data-Axx.csv', sep=',', engine='python')
#      16 # print(df)
#      17
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     993                                  ' "c", "python", or' ' "python-fwf")'.format(
#     994                                      engine=engine))
# --> 995             self._engine = klass(self.f, **self.options)
#     996
#     997     def _failover_to_python(self):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, **kwds)
#    1983         f, handles = _get_handle(f, mode, encoding=self.encoding,
#    1984                                  compression=self.compression,
# -> 1985                                  memory_map=self.memory_map)
#    1986         self.handles.extend(handles)
#    1987
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     383         elif is_text:
#     384             # Python 3 and no explicit encoding
# --> 385             f = open(path_or_buf, mode, errors='replace')
#     386         else:
#     387             # Python 3 and binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resultados/random-var-m-data-Axx.csv'
