# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random

import math

# %%
df = pd.read_csv('./exp_training_entries_vs_accuracy_vs_tiempo10_20000.csv', sep=',', engine='python')
ax1 = df.plot(kind='line', x='training entries', y='tiempo', grid=True, label="knn + pca")

plt.title('Tiempo para distinta cantidad de training entries en ms')
plt.ylabel(r'tiempo')
plt.savefig('./img/training-entries-tiempo.png')
plt.show()

# %%
df = pd.read_csv('./exp_training_entries_vs_accuracy_vs_tiempo10_20000.csv', sep=',', engine='python')
ax1 = df.plot(kind='line', x='training entries', y='accuracy', grid=True, label="knn + pca")

plt.title('Tiempo para distinta cantidad de training entries en ms')
plt.ylabel(r'accuracy')
plt.savefig('./img/training-entries-accuracy.png')
plt.show()

# %%
df = pd.read_csv('./exp_training_entries_vs_accuracy_vs_tiempo10_25000.csv', sep=',', engine='python')
ax1 = df.plot(kind='line', x='training entries', y='tiempo', grid=True, label="knn + pca")

plt.title('Tiempo para distinta cantidad de entries en ms')
plt.ylabel(r'tiempo')
plt.savefig('./img/tiempo-training-entries-accuracy-mejork-mejoralpha.png')
plt.show()

# %%
df = pd.read_csv('./exp_training_entries_vs_accuracy_vs_tiempo10_25000.csv', sep=',', engine='python')
ax1 = df.plot(kind='line', x='training entries', y='accuracy', grid=True, label="knn + pca")

plt.title('Accuracy para distinta cantidad de training entries en ms')
plt.ylabel(r'accuracy')
plt.savefig('./img/accuracy-training-entries-accuracy-mejork-mejoralpha.png')
plt.show()

# %%
df = pd.read_csv('./exp_training_entries_vs_accuracy_vs_tiempo10_25000.csv', sep=',', engine='python')
ax1 = df.plot(kind='line', x='training entries', y='recall', grid=True, label="knn + pca")

plt.title('Recall para distinta cantidad de training entries en ms')
plt.ylabel(r'recall')
plt.savefig('./img/recall-training-entries-accuracy-mejork-mejoralpha.png')
plt.show()
