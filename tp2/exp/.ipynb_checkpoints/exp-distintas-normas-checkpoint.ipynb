# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import random

import math

# %%
df1 = pd.read_csv('./res/exp_distintas_normas5.csv', sep=',', engine='python')
df = df1.loc[df1['norma'] == '1']
df2 = df1.loc[df1['norma'] == '2']
df3 = df1.loc[df1['norma'] == '3']
df4 = df1.loc[df1['norma'] == '4']
df5 = df1.loc[df1['norma'] == '5']
dfchi = df1.loc[df1['norma'] == 'chi2']
dfinf = df1.loc[df1['norma'] == 'inf']
ax1 = df.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma 1")
ax1 = df2.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma 2", ax = ax1)
ax1 = df3.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma 3")
ax1 = df4.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma 4")
ax1 = df5.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma 5")
ax1 = dfchi.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma chi2")
ax1 = dfinf.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma inf")
ax1 = df2.plot(kind='line', x='alpha', y='accuracy', grid=True, label="Frontera Exacto")
ax1 = df3.plot(kind='line', x='', y='fronteraHConstructiva', color='g', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = df4.plot(kind='line', x='m', y='fronteraBLocal', color='r', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df5.plot(kind='line', x='m', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)
ax1 = df.plot(kind='line', x='k', y='fronteraHConstructiva', color='g', grid=True, label="Frontera H. Constr.", ax = ax1)
ax1 = dfchi.plot(kind='line', x='m', y='fronteraBLocal', color='r', grid=True, label="Frontera B. Local", ax = ax1)
ax1 = df5inf.plot(kind='line', x='m', y='fronteraGrasp', color='y', grid=True, label="Frontera Grasp", ax = ax1)

plt.title('Grafos tipo random')
plt.ylabel(r'Frontera')
plt.savefig('./img/fronteras-comp-algoritmos-con-exacto-variando-m.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-954621a2a028> in <module>
#      11 ax1 = df3.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma 3")
#      12 ax1 = df4.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma 4")
# ---> 13 ax1 = df5.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma 5")
#      14 ax1 = dfchi.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma chi2")
#      15 ax1 = dfinf.plot(kind='line', x='alpha', y='accuracy', grid=True, label="norma inf")
#
# ~/.local/lib/python3.5/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...
